# %% [markdown]
# Duvan Stiven Tique Osorio
#
# ## Punto 1: Pídale a varios LLMs de IAGen una definición de IA, compárelas con lo visto en el capítulo.
# ### COPILOT
# La Inteligencia Artificial (IA) se puede definir como el campo de la informática que busca desarrollar sistemas capaces de realizar tareas que normalmente requieren inteligencia humana. Estas tareas incluyen el razonamiento, el aprendizaje, la percepción, la comprensión del lenguaje natural y la toma de decisiones.
# ### DEEPSEEK
# La Inteligencia Artificial es la rama de la informática que se encarga de crear sistemas capaces de realizar tareas que, normalmente, requieren de la inteligencia humana. Esto incluye habilidades como el razonamiento, el aprendizaje, la percepción visual, el reconocimiento del habla y la toma de decisiones.
# ### CHATGPT
# La inteligencia artificial (IA) es una rama de la informática que desarrolla sistemas capaces de realizar tareas que normalmente requieren inteligencia humana, como aprender, razonar, resolver problemas, comprender el lenguaje, reconocer imágenes y tomar decisiones.
# ### CLAUDE
# La Inteligencia Artificial (IA) es el campo de la ingeniería y la ciencia de la computación dedicado a crear sistemas capaces de realizar tareas que normalmente requerirían inteligencia humana: percibir su entorno, aprender de datos o experiencia, razonar sobre información incompleta o incierta, tomar decisiones y actuar para lograr un objetivo determinado.
# ## Punto 2: Dé una definición propia de inteligencia artificial.
# La inteligencia artificcial es una herramienta computacional, capaz de realizar tareas de manera autonoma tales como, analizar imagenes, tomar decisiones, razonar y resolver problemas. De tal manera que con el conocimiento con el cual fue desarollada esta heramienta permita realizar las tareas que normalmente hace una persona en estos ambitos.
# ## Punto 3: Haga un análisis de lo discutido en el documento con respecto al video.
# A media que avanza la tecnología, tambíen se incrementa el impacto que tiene esta sobre la vida de las personas y el planteta. El principal riesgo de cualquier tecnología con gran potencial es que se utilize para causar daño a los demás, los robot autoreplicadores tienen gran potencial en el campo de la medicina y la exploración espacial, pero de igual manera se puede perder el control sobre esta tecnología facilmente. Por lo que al final el problema es que la tecnología avanza mucho mas rapido que los valores morales y sociales por lo que en mi opinion estas tecnología deberian esta controladas y restringidas al publico.
# ## Punto 4: Haga un resumen sobre Cosmos de NVIDIA
#  NVIDIA Cosmos es un modelo abierto de IA física diseñado para razonar, simular y generar mundos basados en datos reales y sintéticos. Se presenta como un omnimodelo que integra visión, lenguaje, sonido y acciones para comprender y predecir escenarios complejos del mundo físico.
# ## Punto 5: Investigue sobre los planes del gobierno con respecto a la IA.
# Actualmente, el Gobierno de Colombia impulsa la Inteligencia Artificial como política de Estado, con el CONPES 4144 (2025) y programas activos en 2026 que buscan un desarrollo ético, soberano y aplicado en sectores como salud, agro, energía, ciberseguridad y educación. esto apenas son lineamientos generales por que actualmente, no se ha implementado inteligencia artificial en ninguna dependencia del estado, pero se ha mostrado la voluntad de financiar proyectos con IA en el pais pero es muy reciente como para que ya se tenga algo.
